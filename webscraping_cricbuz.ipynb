# %% [markdown]
# <a href="https://colab.research.google.com/github/CHANDRALEKAGOMATHISANKAR1101/CHANDRALEKAGOMATHISANKAR1101/blob/main/webscraping_cricbuz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import time
from bs4 import BeautifulSoup
import requests

# %%
try:
        
    page=requests.get('https://www.cricbuzz.com/')                            
    
except Exception as e:                                   
    error_type, error_obj, error_info = sys.exc_info()      
    print ('ERROR FOR LINK:',url)                          
    print (error_type, 'Line:', error_info.tb_lineno)     
                                                 
time.sleep(2)   
soup=BeautifulSoup(page.text,'html.parser')
links=soup.find_all('div',attrs={'class':'cb-nws-intr'})

# %%
page
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
links
# Out:
# [<div class="cb-nws-intr">The free-flowing Punjab Kings lineup may have to alter their approach to tackle spin in an afternoon game at the venue</div>,
#  <div class="cb-nws-intr">On form, the Sanju Samson-led side have looked better than the traditional heavyweights of the IPL</div>,
#  <div class="cb-nws-intr">The Titans batter smashed a 24-ball 51*, taking his IPL 2023 tally closer to 200 with those runs coming at a strike-rate of 165.83</div>,
#  <div class="cb-nws-intr">After SRH scored at just 5.25 in the three overs after the PowerPlay, Klaasen provided the oomph and powered SRH to an above-par and match-winning total in Delhi</div>,
#  <div class="cb-nws-intr">A detailed look at how the Impact Sub continues to hold sway on the trends as the league phase of IPL 2023 passes the halfway stage mark</div>,
#  <div class="cb-nws-intr">Daryl Mitchell's second successive ton not enough to prevent New Zealand from slipping to 0-2 in the series</div>,
# ...

# %%
for i in links:
    print(i.text)
    print("\n")
# Out:
# The free-flowing Punjab Kings lineup may have to alter their approach to tackle spin in an afternoon game at the venue
#
#
# On form, the Sanju Samson-led side have looked better than the traditional heavyweights of the IPL
#
#
# The Titans batter smashed a 24-ball 51*, taking his IPL 2023 tally closer to 200 with those runs coming at a strike-rate of 165.83
#
#
# After SRH scored at just 5.25 in the three overs after the PowerPlay, Klaasen provided the oomph and powered SRH to an above-par and match-winning total in Delhi
#
#
# A detailed look at how the Impact Sub continues to hold sway on the trends as the league phase of IPL 2023 passes the halfway stage mark
#
#
# Daryl Mitchell's second successive ton not enough to prevent New Zealand from slipping to 0-2 in the series
#
#
# The former England captain took up the board role in 2020 but now feels that the time is right to step away
#
#
# ...
